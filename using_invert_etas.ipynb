# %%
import numpy as np
import datetime as dt

from inversion import invert_etas_params

if __name__ == '__main__':
    theta_0 = {
        'log10_mu': -5.8,
        'log10_k0': -2.6,
        'a': 1.8,
        'log10_c': -2.5,
        'omega': -0.02,
        'log10_tau': 3.5,
        'log10_d': -0.85,
        'gamma': 1.3,
        'rho': 0.66
    }

    inversion_meta = {
        "fn_catalog": "19970101-20220116_mini.csv",
        "data_path": "",
        "auxiliary_start": dt.datetime(1997, 1, 1),
        "timewindow_start": dt.datetime(2002, 4, 16),
        "timewindow_end": dt.datetime(2022, 1, 16),
        "theta_0": theta_0,
        "mc": 5.4,
        "delta_m": 0.1,
        "coppersmith_multiplier": 100,
    }

    parameters = invert_etas_params(
        inversion_meta,
        globe=True
    )
# Out:
# PREPARING METADATA...
#
#   using catalog: 19970101-20220116_mini.csv
#   Data will be stored in /home/amand4/notebooks/surface-load-quakes/etas
#   Time Window: 1997-01-01 00:00:00 (aux) - 2002-04-16 00:00:00 (start) - 2022-01-16 00:00:00 (end)
#   m_ref is 5.4 and delta_m is 0.1
#   coppersmith multiplier is 100
#   Region has 511201962.31054497 square km
#
#
# INITIALIZING
#
#   reading data..
#
#   15766 out of 15766 events lie within target region.
#   15764 events are within time window
#
#
#   calculating distances..
#
#     beta is 2.3629393184057337
#
#   number of sources: 15764
#   number of targets: 12573
#
#    took 0:01:41.371130 to prepare the data
#
#   preparing source and target events..
#
#   beta of primary catalog is 2.3629393184057337
#   using input initial values for theta
#
#
#
# START INVERSION!
#
# iteration 0
#
#   expectation
#
#     calculating gij
#     calculating Pij
# /home/amand4/notebooks/surface-load-quakes/etas/inversion.py:443: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   Pij_0["tot_rates"] = Pij_0["tot_rates"].add((Pij_0["gij"] * Pij_0["xi_plus_1"]).sum(level=1)).add(target_events_0["mu"])
# /home/amand4/notebooks/surface-load-quakes/etas/inversion.py:448: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   target_events_0["P_triggered"] = target_events_0["P_triggered"].add(Pij_0["Pij"].sum(level=1)).fillna(0)
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:01.917524
#       n_hat: 10020.345827594418
#
#   maximization
# /home/amand4/notebooks/surface-load-quakes/etas/inversion.py:459: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   source_events_0["l_hat"] = (Pij_0["Pij"] * Pij_0["zeta_plus_1"]).sum(level=0)
#     optimization step took  0:03:37.147185
#     new parameters:
#
# {   'a': 2.6434586008615466,
#     'gamma': 1.2636774305120706,
#     'log10_c': -2.113427547840283,
#     'log10_d': 1.5174958144021526,
#     'log10_k0': -1.077222456972917,
#     'log10_mu': -8.565946137279024,
#     'log10_tau': 3.923519331161894,
#     'omega': 0.22553602195254524,
#     'rho': 1.0186906189877252}
#
#     difference to previous: 8.950319089319617
#     branching ratio: 0.9787785489355433
#
# iteration 1
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.191685
#       n_hat: 6210.049267334269
#
#   maximization
#
#     optimization step took  0:06:57.425115
#     new parameters:
#
# {   'a': 2.609299975906599,
#     'gamma': 1.3008818755672316,
#     'log10_c': -2.5795754825356902,
#     'log10_d': 1.83824759306589,
#     'log10_k0': -0.48564031489108983,
#     'log10_mu': -8.773733802015824,
#     'log10_tau': 3.6947741697555005,
#     'omega': -0.060561934756752756,
#     'rho': 0.9842843589785454}
#
#     difference to previous: 2.2068819683127514
#     branching ratio: 0.21717955580913842
#
# iteration 2
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:03.493657
#       n_hat: 2877.192299075743
#
#   maximization
#
#     optimization step took  0:07:29.116364
#     new parameters:
#
# {   'a': 2.351403138832959,
#     'gamma': 1.248439825706935,
#     'log10_c': -3.1370017416132447,
#     'log10_d': 2.056218646285415,
#     'log10_k0': -0.3928796580536248,
#     'log10_mu': -9.107859958451789,
#     'log10_tau': 3.7267430810176663,
#     'omega': -0.186532920567,
#     'rho': 0.911695048017635}
#
#     difference to previous: 1.743152220537769
#     branching ratio: 0.5637895390473319
#
# iteration 3
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:04.884336
#       n_hat: 1413.5805912239723
#
#   maximization
#
#     optimization step took  0:08:07.269174
#     new parameters:
#
# {   'a': 2.0426125078073736,
#     'gamma': 1.1703284103850786,
#     'log10_c': -3.3821701326668405,
#     'log10_d': 2.1568341424307156,
#     'log10_k0': -0.5857634484164168,
#     'log10_mu': -9.416508274095158,
#     'log10_tau': 3.732730937533446,
#     'omega': -0.22499010783222329,
#     'rho': 0.7944744571680303}
#
#     difference to previous: 1.3958836741831069
#     branching ratio: 0.8836151924703153
#
# iteration 4
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:03.534161
#       n_hat: 826.5441276476712
#
#   maximization
#
#     optimization step took  0:06:47.655941
#     new parameters:
#
# {   'a': 1.7740341356321037,
#     'gamma': 1.0762668660447792,
#     'log10_c': -3.4608277192915176,
#     'log10_d': 2.1913882467615426,
#     'log10_k0': -0.8148024248314175,
#     'log10_mu': -9.649562802977032,
#     'log10_tau': 3.723232195925745,
#     'omega': -0.23616861603493722,
#     'rho': 0.6917637390224802}
#
#     difference to previous: 1.0613330807239139
#     branching ratio: 1.0227470706343988
#
# iteration 5
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:03.655770
#       n_hat: 552.8344216746314
#
#   maximization
#
#     optimization step took  0:08:19.659396
#     new parameters:
#
# {   'a': 1.5724272441667697,
#     'gamma': 0.9779043235758687,
#     'log10_c': -3.48326600190234,
#     'log10_d': 2.2054632529416307,
#     'log10_k0': -0.9734807590972655,
#     'log10_mu': -9.824233771561431,
#     'log10_tau': 3.7125174589984984,
#     'omega': -0.23938800901465992,
#     'rho': 0.6242686890413525}
#
#     difference to previous: 0.7512612054634992
#     branching ratio: 1.0716799974151203
#
# iteration 6
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:01.935666
#       n_hat: 410.50059230120416
#
#   maximization
#
#     optimization step took  0:03:14.048709
#     new parameters:
#
# {   'a': 1.4283735213274045,
#     'gamma': 0.8881480574231507,
#     'log10_c': -3.489951332262225,
#     'log10_d': 2.215842965100414,
#     'log10_k0': -1.0642824339810801,
#     'log10_mu': -9.953515059586206,
#     'log10_tau': 3.704497568256186,
#     'omega': -0.24036110095467905,
#     'rho': 0.5846536353259207}
#
#     difference to previous: 0.5195660308171037
#     branching ratio: 1.0899184523855419
#
# iteration 7
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.228110
#       n_hat: 331.25390459956697
#
#   maximization
#
#     optimization step took  0:07:45.041972
#     new parameters:
#
# {   'a': 1.3265093421459617,
#     'gamma': 0.8139108738266767,
#     'log10_c': -3.492698645265997,
#     'log10_d': 2.225943087247819,
#     'log10_k0': -1.1114564025341416,
#     'log10_mu': -10.046667841526899,
#     'log10_tau': 3.6993156708496553,
#     'omega': -0.24072457706146072,
#     'rho': 0.5623129218075481}
#
#     difference to previous: 0.35716163545453383
#     branching ratio: 1.0971075518076123
#
# iteration 8
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:06.097629
#       n_hat: 285.0525458628889
#
#   maximization
#
#     optimization step took  0:06:07.096368
#     new parameters:
#
# {   'a': 1.2543041490840074,
#     'gamma': 0.756188465268249,
#     'log10_c': -3.4947977952395024,
#     'log10_d': 2.2354336207660777,
#     'log10_k0': -1.1343310434458485,
#     'log10_mu': -10.111903923544165,
#     'log10_tau': 3.6961826365441928,
#     'omega': -0.24091204926848317,
#     'rho': 0.54979269142604}
#
#     difference to previous: 0.2454687449351122
#     branching ratio: 1.1000143378745222
#
# iteration 9
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:03.521623
#       n_hat: 257.2362010795527
#
#   maximization
#
#     optimization step took  0:05:22.730783
#     new parameters:
#
# {   'a': 1.20274875688936,
#     'gamma': 0.7127544064006202,
#     'log10_c': -3.4964719623101743,
#     'log10_d': 2.2437500775886936,
#     'log10_k0': -1.1445571129639478,
#     'log10_mu': -10.156496760472692,
#     'log10_tau': 3.694301760710233,
#     'omega': -0.2410430318343872,
#     'rho': 0.5427044494724185}
#
#     difference to previous: 0.16889908175567522
#     branching ratio: 1.1011452581466576
#
# iteration 10
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:03.955372
#       n_hat: 240.10432146351474
#
#   maximization
#
#     optimization step took  0:07:12.765080
#     new parameters:
#
# {   'a': 1.1656674181574798,
#     'gamma': 0.6804849796020128,
#     'log10_c': -3.4977597748811164,
#     'log10_d': 2.2506532527801424,
#     'log10_k0': -1.1483761019305372,
#     'log10_mu': -10.186428870996217,
#     'log10_tau': 3.6932076022307476,
#     'omega': -0.2411271053218154,
#     'rho': 0.5386532944135479}
#
#     difference to previous: 0.11652223980877693
#     branching ratio: 1.101507376633416
#
# iteration 11
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.611739
#       n_hat: 229.40775228588342
#
#   maximization
#
#     optimization step took  0:02:25.768018
#     new parameters:
#
# {   'a': 1.1388914538327604,
#     'gamma': 0.6568203735002016,
#     'log10_c': -3.4979439318770895,
#     'log10_d': 2.256116160363269,
#     'log10_k0': -1.1492301640797467,
#     'log10_mu': -10.206220757919215,
#     'log10_tau': 3.692555708878697,
#     'omega': -0.2411752764842128,
#     'rho': 0.5362828251109755}
#
#     difference to previous: 0.07980411789485875
#     branching ratio: 1.101538371158874
#
# iteration 12
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:01.896320
#       n_hat: 222.66942397453994
#
#   maximization
#
#     optimization step took  0:02:52.541096
#     new parameters:
#
# {   'a': 1.1194274868464251,
#     'gamma': 0.6394034191079724,
#     'log10_c': -3.4997108576627047,
#     'log10_d': 2.260415264361753,
#     'log10_k0': -1.1487396643801597,
#     'log10_mu': -10.219168262032019,
#     'log10_tau': 3.692132215892487,
#     'omega': -0.24122362732744979,
#     'rho': 0.5348880431939261}
#
#     difference to previous: 0.058251580721550705
#     branching ratio: 1.1014130685246224
#
# iteration 13
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.198604
#       n_hat: 218.4003550090872
#
#   maximization
#
#     optimization step took  0:03:48.083015
#     new parameters:
#
# {   'a': 1.1052775504235366,
#     'gamma': 0.62666152916195,
#     'log10_c': -3.5005322066794364,
#     'log10_d': 2.263676403950944,
#     'log10_k0': -1.1478072824562249,
#     'log10_mu': -10.227575507697356,
#     'log10_tau': 3.6918627588442727,
#     'omega': -0.241253647135656,
#     'rho': 0.5340419564989267}
#
#     difference to previous: 0.04145950611552546
#     branching ratio: 1.1012375944480084
#
# iteration 14
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.296123
#       n_hat: 215.68753806433332
#
#   maximization
#
#     optimization step took  0:02:47.847797
#     new parameters:
#
# {   'a': 1.0949643510074039,
#     'gamma': 0.6173118046917752,
#     'log10_c': -3.5006693544172496,
#     'log10_d': 2.2661644562563352,
#     'log10_k0': -1.1466768196208748,
#     'log10_mu': -10.233003794395488,
#     'log10_tau': 3.69169794106734,
#     'omega': -0.24126413650541528,
#     'rho': 0.533549704528886}
#
#     difference to previous: 0.0295144325797268
#     branching ratio: 1.10105218330369
#
# iteration 15
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.718441
#       n_hat: 213.97044093675845
#
#   maximization
#
#     optimization step took  0:03:13.397698
#     new parameters:
#
# {   'a': 1.0874035227860854,
#     'gamma': 0.6104067185734545,
#     'log10_c': -3.5009212936911687,
#     'log10_d': 2.26807059388897,
#     'log10_k0': -1.1455919571459,
#     'log10_mu': -10.236475066030074,
#     'log10_tau': 3.6915873134270827,
#     'omega': -0.24127260696875316,
#     'rho': 0.5332618183972171}
#
#     difference to previous: 0.021587109591017867
#     branching ratio: 1.1008802460666829
#
# iteration 16
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:01.925737
#       n_hat: 212.88513041645467
#
#   maximization
#
#     optimization step took  0:01:57.872163
#     new parameters:
#
# {   'a': 1.0818985387423747,
#     'gamma': 0.6053770976851797,
#     'log10_c': -3.501232438286257,
#     'log10_d': 2.26950050151249,
#     'log10_k0': -1.1446498299246521,
#     'log10_mu': -10.238683519743464,
#     'log10_tau': 3.6915133672868143,
#     'omega': -0.24127656899171798,
#     'rho': 0.5330931517302515}
#
#     difference to previous: 0.015672812915430545
#     branching ratio: 1.1007295066222507
#
# iteration 17
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.008154
#       n_hat: 212.1997420806245
#
#   maximization
#
#     optimization step took  0:02:21.355586
#     new parameters:
#
# {   'a': 1.0778676622706778,
#     'gamma': 0.6016893370789255,
#     'log10_c': -3.5014575683718023,
#     'log10_d': 2.2705525298266984,
#     'log10_k0': -1.1438972352458936,
#     'log10_mu': -10.240083995974977,
#     'log10_tau': 3.691465825288758,
#     'omega': -0.24127977500345618,
#     'rho': 0.5329917616876938}
#
#     difference to previous: 0.011301004440328666
#     branching ratio: 1.1006113807743325
#
# iteration 18
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.293876
#       n_hat: 211.76999523436666
#
#   maximization
#
#     optimization step took  0:02:27.414652
#     new parameters:
#
# {   'a': 1.074880209347563,
#     'gamma': 0.59893674284293,
#     'log10_c': -3.5016550513757507,
#     'log10_d': 2.2713530427002526,
#     'log10_k0': -1.143276413222199,
#     'log10_mu': -10.240964420832876,
#     'log10_tau': 3.6914268321987556,
#     'omega': -0.24128201375232855,
#     'rho': 0.5329330488776252}
#
#     difference to previous: 0.008339234567149773
#     branching ratio: 1.100504632623513
#
# iteration 19
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.302763
#       n_hat: 211.5004452789646
#
#   maximization
#
#     optimization step took  0:03:03.421980
#     new parameters:
#
# {   'a': 1.072692816123364,
#     'gamma': 0.5969018202993448,
#     'log10_c': -3.5018341910608513,
#     'log10_d': 2.2719615452202153,
#     'log10_k0': -1.142762182122079,
#     'log10_mu': -10.24151756162821,
#     'log10_tau': 3.6914035652124717,
#     'omega': -0.2412830454274338,
#     'rho': 0.5329068017016777}
#
#     difference to previous: 0.006127875705638469
#     branching ratio: 1.100427537330755
#
# iteration 20
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.792917
#       n_hat: 211.33437236192958
#
#   maximization
#
#     optimization step took  0:03:41.655347
#     new parameters:
#
# {   'a': 1.07109510905943,
#     'gamma': 0.595431695629667,
#     'log10_c': -3.5020009487383064,
#     'log10_d': 2.2723994240753758,
#     'log10_k0': -1.1423844862227897,
#     'log10_mu': -10.241858709292316,
#     'log10_tau': 3.691387538781379,
#     'omega': -0.24128398003634657,
#     'rho': 0.5328890297524705}
#
#     difference to previous: 0.004426044818834962
#     branching ratio: 1.100362763950026
#
# iteration 21
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:01.922683
#       n_hat: 211.23144984368327
#
#   maximization
#
#     optimization step took  0:01:50.463176
#     new parameters:
#
# {   'a': 1.0699186952191015,
#     'gamma': 0.5943459830789024,
#     'log10_c': -3.5020631256962216,
#     'log10_d': 2.2727247011140133,
#     'log10_k0': -1.1420925172966587,
#     'log10_mu': -10.242070267730188,
#     'log10_tau': 3.691378544001223,
#     'omega': -0.24128329676573002,
#     'rho': 0.532879974493264}
#
#     difference to previous: 0.0031718410616278503
#     branching ratio: 1.1003144880094922
#
# iteration 22
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.007570
#       n_hat: 211.16898270445716
#
#   maximization
#
#     optimization step took  0:02:00.800575
#     new parameters:
#
# {   'a': 1.0690372762171982,
#     'gamma': 0.5935232454137855,
#     'log10_c': -3.502071369394629,
#     'log10_d': 2.2729485062220847,
#     'log10_k0': -1.141924668861695,
#     'log10_mu': -10.242198719937967,
#     'log10_tau': 3.691370152148827,
#     'omega': -0.2412846476845759,
#     'rho': 0.5328617276280572}
#
#     difference to previous: 0.0022604957526903557
#     branching ratio: 1.1002726662864262
#
# iteration 23
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.290788
#       n_hat: 211.127923604663
#
#   maximization
#
#     optimization step took  0:01:40.853714
#     new parameters:
#
# {   'a': 1.06839570910718,
#     'gamma': 0.5929434809290858,
#     'log10_c': -3.502152264034844,
#     'log10_d': 2.2731167062566517,
#     'log10_k0': -1.141770223266626,
#     'log10_mu': -10.242283171139302,
#     'log10_tau': 3.691368197988368,
#     'omega': -0.24128351414330862,
#     'rho': 0.532855744445517}
#
#     difference to previous: 0.0017183939501703438
#     branching ratio: 1.1002446474804524
#
# iteration 24
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.303514
#       n_hat: 211.10256721521358
#
#   maximization
#
#     optimization step took  0:01:52.121099
#     new parameters:
#
# {   'a': 1.0679390414965333,
#     'gamma': 0.5925179764408729,
#     'log10_c': -3.502161732653484,
#     'log10_d': 2.273257298794872,
#     'log10_k0': -1.141609319228994,
#     'log10_mu': -10.242335332886364,
#     'log10_tau': 3.6913632325461405,
#     'omega': -0.24128204975052392,
#     'rho': 0.5328641279988361}
#
#     difference to previous: 0.0012601124287457965
#     branching ratio: 1.1002250704893104
#
# iteration 25
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:04.628359
#       n_hat: 211.0903693309699
#
#   maximization
#
#     optimization step took  0:02:30.454648
#     new parameters:
#
# {   'a': 1.0676033719263587,
#     'gamma': 0.5922058291958961,
#     'log10_c': -3.5021837908492537,
#     'log10_d': 2.2733624950134477,
#     'log10_k0': -1.1415002938130112,
#     'log10_mu': -10.242360427924016,
#     'log10_tau': 3.6913585014269614,
#     'omega': -0.2412823487925175,
#     'rho': 0.5328673862713011}
#
#     difference to previous: 0.0009174801167684821
#     branching ratio: 1.1002067007973004
#
# stopping here. converged after 26 iterations.
#   last expectation step
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:01.922364
#       n_hat: 211.08283997834715
