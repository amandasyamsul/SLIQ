# %%
import numpy as np
import datetime as dt

from inversion import invert_etas_params

if __name__ == '__main__':
    theta_0 = {
        'log10_mu': -5.8,
        'log10_k0': -2.6,
        'a': 1.8,
        'log10_c': -2.5,
        'omega': -0.02,
        'log10_tau': 3.5,
        'log10_d': -0.85,
        'gamma': 1.3,
        'rho': 0.66
    }

    inversion_meta = {
        "fn_catalog": "19970101-20220116_mini.csv",
        "data_path": "",
        "auxiliary_start": dt.datetime(1997, 1, 1),
        "timewindow_start": dt.datetime(2002, 4, 16),
        "timewindow_end": dt.datetime(2022, 1, 16),
        "theta_0": theta_0,
        "mc": 5.4,
        "delta_m": 0.1,
        "coppersmith_multiplier": 100,
    }

    parameters = invert_etas_params(
        inversion_meta,
        globe=True
    )
# Out:
# PREPARING METADATA...
#
#   using catalog: 19970101-20220116_mini.csv
#   Data will be stored in /home/amand4/notebooks/surface-load-quakes/etas
#   Time Window: 1997-01-01 00:00:00 (aux) - 2002-04-16 00:00:00 (start) - 2022-01-16 00:00:00 (end)
#   m_ref is 5.4 and delta_m is 0.1
#   coppersmith multiplier is 100
#   Region has 511201962.31054497 square km
#
#
# INITIALIZING
#
#   reading data..
#
#   15766 out of 15766 events lie within target region.
#   15764 events are within time window
#
#
#   calculating distances..
#
#     beta is 2.3629393184057337
#
#   number of sources: 15764
#   number of targets: 12573
#
#    took 0:01:43.028515 to prepare the data
#
#   preparing source and target events..
#
#   beta of primary catalog is 2.3629393184057337
#   using input initial values for theta
#
#
#
# START INVERSION!
#
# iteration 0
#
#   expectation
#
#     calculating gij
#     calculating Pij
# /home/amand4/notebooks/surface-load-quakes/etas/inversion.py:443: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   Pij_0["tot_rates"] = Pij_0["tot_rates"].add((Pij_0["gij"] * Pij_0["xi_plus_1"]).sum(level=1)).add(target_events_0["mu"])
# /home/amand4/notebooks/surface-load-quakes/etas/inversion.py:448: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   target_events_0["P_triggered"] = target_events_0["P_triggered"].add(Pij_0["Pij"].sum(level=1)).fillna(0)
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.109309
#       n_hat: 10051.64925709923
#
#   maximization
# /home/amand4/notebooks/surface-load-quakes/etas/inversion.py:459: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   source_events_0["l_hat"] = (Pij_0["Pij"] * Pij_0["zeta_plus_1"]).sum(level=0)
#     optimization step took  0:04:33.781199
#     new parameters:
#
# {   'a': 2.6495745173901244,
#     'gamma': 1.2620567440055854,
#     'log10_c': -2.110060366939704,
#     'log10_d': 1.5189127039323864,
#     'log10_k0': -1.0924347732453648,
#     'log10_mu': -8.564591521789813,
#     'log10_tau': 3.918727939428171,
#     'omega': 0.22983286047100698,
#     'rho': 1.0242738796743742}
#
#     difference to previous: 8.951361538495224
#     branching ratio: 0.9787785489355433
#
# iteration 1
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.332911
#       n_hat: 6348.716869615564
#
#   maximization
#
#     optimization step took  0:05:41.375323
#     new parameters:
#
# {   'a': 2.62766385865876,
#     'gamma': 1.3028088902921446,
#     'log10_c': -2.5520196421859667,
#     'log10_d': 1.8368269772266952,
#     'log10_k0': -0.5029699148837612,
#     'log10_mu': -8.764142888171135,
#     'log10_tau': 3.6841591925031363,
#     'omega': -0.05279470273908105,
#     'rho': 0.9919431719110621}
#
#     difference to previous: 2.161079596199855
#     branching ratio: 0.20460298500370322
#
# iteration 2
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.325454
#       n_hat: 3066.7938282746873
#
#   maximization
#
#     optimization step took  0:04:20.668957
#     new parameters:
#
# {   'a': 2.3805032283956318,
#     'gamma': 1.252685522222024,
#     'log10_c': -3.1003095013176094,
#     'log10_d': 2.0523587761905673,
#     'log10_k0': -0.38838172261270976,
#     'log10_mu': -9.080144267079572,
#     'log10_tau': 3.719593951162585,
#     'omega': -0.1798217604074792,
#     'rho': 0.9261889232425466}
#
#     difference to previous: 1.7199112926046147
#     branching ratio: 0.5143962601388684
#
# iteration 3
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.330468
#       n_hat: 1557.0304788528467
#
#   maximization
#
#     optimization step took  0:04:51.098686
#     new parameters:
#
# {   'a': 2.077168207751317,
#     'gamma': 1.1765201135813739,
#     'log10_c': -3.349796278388717,
#     'log10_d': 2.1571665699928686,
#     'log10_k0': -0.5570962359492141,
#     'log10_mu': -9.374531733714365,
#     'log10_tau': 3.728393958648766,
#     'omega': -0.21983414551173283,
#     'rho': 0.8140956793220485}
#
#     difference to previous: 1.3578026166406048
#     branching ratio: 0.808107525082784
#
# iteration 4
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.326383
#       n_hat: 935.3540977531962
#
#   maximization
#
#     optimization step took  0:05:15.657767
#     new parameters:
#
# {   'a': 1.8063169833558461,
#     'gamma': 1.0845084678481527,
#     'log10_c': -3.4342879599833545,
#     'log10_d': 2.1948182233402185,
#     'log10_k0': -0.7820243304231107,
#     'log10_mu': -9.595852794462557,
#     'log10_tau': 3.719757066807015,
#     'omega': -0.23205579319409034,
#     'rho': 0.7104859992688196}
#
#     difference to previous: 1.0557235798701055
#     branching ratio: 0.947695106969028
#
# iteration 5
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.328539
#       n_hat: 639.5642106031482
#
#   maximization
#
#     optimization step took  0:05:05.685596
#     new parameters:
#
# {   'a': 1.5991992086749673,
#     'gamma': 0.987168383241308,
#     'log10_c': -3.46038303481301,
#     'log10_d': 2.2098663534406957,
#     'log10_k0': -0.9464099131674311,
#     'log10_mu': -9.760944694621449,
#     'log10_tau': 3.709077238670812,
#     'omega': -0.23587989571166978,
#     'rho': 0.6397000692590812}
#
#     difference to previous: 0.7603684077845891
#     branching ratio: 1.0021430288635256
#
# iteration 6
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.331478
#       n_hat: 482.68373454965507
#
#   maximization
#
#     optimization step took  0:04:29.200135
#     new parameters:
#
# {   'a': 1.4495389987714264,
#     'gamma': 0.8969934114496956,
#     'log10_c': -3.4691085875723533,
#     'log10_d': 2.2202898858993256,
#     'log10_k0': -1.0437939361883968,
#     'log10_mu': -9.8831661834416,
#     'log10_tau': 3.7008120045974917,
#     'omega': -0.23718499059625184,
#     'rho': 0.5970013813872614}
#
#     difference to previous: 0.5308587955839665
#     branching ratio: 1.0257854599023826
#
# iteration 7
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.321708
#       n_hat: 393.8300983104777
#
#   maximization
#
#     optimization step took  0:04:57.298675
#     new parameters:
#
# {   'a': 1.3430141676327327,
#     'gamma': 0.8214168406290572,
#     'log10_c': -3.4729530499844645,
#     'log10_d': 2.230300206209453,
#     'log10_k0': -1.095715437710401,
#     'log10_mu': -9.971519943819388,
#     'log10_tau': 3.6953365387083137,
#     'omega': -0.23772776893363137,
#     'rho': 0.5724456435979108}
#
#     difference to previous: 0.36680542859727
#     branching ratio: 1.0374622570185916
#
# iteration 8
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.325592
#       n_hat: 341.3124012280971
#
#   maximization
#
#     optimization step took  0:04:59.091158
#     new parameters:
#
# {   'a': 1.2671087324852175,
#     'gamma': 0.761947524041495,
#     'log10_c': -3.4755162885373814,
#     'log10_d': 2.2398292212893205,
#     'log10_k0': -1.121486643954791,
#     'log10_mu': -10.033676779475154,
#     'log10_tau': 3.6919536669836797,
#     'omega': -0.2380191083543591,
#     'rho': 0.558472774045392}
#
#     difference to previous: 0.25304212796589926
#     branching ratio: 1.043828866680773
#
# iteration 9
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.337803
#       n_hat: 309.3384615233606
#
#   maximization
#
#     optimization step took  0:04:51.792365
#     new parameters:
#
# {   'a': 1.2127378316421782,
#     'gamma': 0.7168417965850167,
#     'log10_c': -3.4775250584962767,
#     'log10_d': 2.2482400489368697,
#     'log10_k0': -1.1333471264511643,
#     'log10_mu': -10.076394926414412,
#     'log10_tau': 3.689905707955911,
#     'omega': -0.23820828748795922,
#     'rho': 0.5504666174928217}
#
#     difference to previous: 0.1747181500555322
#     branching ratio: 1.047559712497096
#
# iteration 10
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.407514
#       n_hat: 289.46649691837575
#
#   maximization
#
#     optimization step took  0:04:52.829163
#     new parameters:
#
# {   'a': 1.1735447134318353,
#     'gamma': 0.6831852435276581,
#     'log10_c': -3.4792791308982376,
#     'log10_d': 2.255288247244148,
#     'log10_k0': -1.1380849863529783,
#     'log10_mu': -10.105230542290135,
#     'log10_tau': 3.6886778681337837,
#     'omega': -0.23833830956488192,
#     'rho': 0.5458269360951804}
#
#     difference to previous: 0.12122296105116892
#     branching ratio: 1.049847439982724
#
# iteration 11
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.528834
#       n_hat: 276.94582295426517
#
#   maximization
#
#     optimization step took  0:03:25.816340
#     new parameters:
#
# {   'a': 1.1451477091543694,
#     'gamma': 0.6583387029792711,
#     'log10_c': -3.47934884419606,
#     'log10_d': 2.260955260786321,
#     'log10_k0': -1.1392841273051997,
#     'log10_mu': -10.12443402840561,
#     'log10_tau': 3.6879452810991102,
#     'omega': -0.23840635864218343,
#     'rho': 0.5431028196139591}
#
#     difference to previous: 0.08290765132674027
#     branching ratio: 1.0512757740059695
#
# iteration 12
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.364229
#       n_hat: 268.9882189394974
#
#   maximization
#
#     optimization step took  0:05:01.381650
#     new parameters:
#
# {   'a': 1.1244977872069664,
#     'gamma': 0.6400685737188718,
#     'log10_c': -3.4814865148684935,
#     'log10_d': 2.2653708299835267,
#     'log10_k0': -1.139025999252363,
#     'log10_mu': -10.13709558834766,
#     'log10_tau': 3.6874501124770203,
#     'omega': -0.2384780623591806,
#     'rho': 0.5414680812154532}
#
#     difference to previous: 0.060594589809922494
#     branching ratio: 1.052200030588162
#
# iteration 13
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.352831
#       n_hat: 263.89671781670563
#
#   maximization
#
#     optimization step took  0:02:59.890853
#     new parameters:
#
# {   'a': 1.109454898146409,
#     'gamma': 0.6266097839671069,
#     'log10_c': -3.481586293114659,
#     'log10_d': 2.268800234123549,
#     'log10_k0': -1.1380273546347308,
#     'log10_mu': -10.145394858906036,
#     'log10_tau': 3.687166296557333,
#     'omega': -0.23850712499214724,
#     'rho': 0.5404968950231744}
#
#     difference to previous: 0.04261284111945007
#     branching ratio: 1.0527810270007296
#
# iteration 14
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.356372
#       n_hat: 260.63232312961145
#
#   maximization
#
#     optimization step took  0:02:43.925013
#     new parameters:
#
# {   'a': 1.0984515364139207,
#     'gamma': 0.616706454819415,
#     'log10_c': -3.481886781653863,
#     'log10_d': 2.2714285344199383,
#     'log10_k0': -1.1368617324567925,
#     'log10_mu': -10.15080057257495,
#     'log10_tau': 3.6869744889653076,
#     'omega': -0.2385270723341696,
#     'rho': 0.5399111095968734}
#
#     difference to previous: 0.031204355922974186
#     branching ratio: 1.0531641953376365
#
# iteration 15
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.340600
#       n_hat: 258.5346941953858
#
#   maximization
#
#     optimization step took  0:04:39.673981
#     new parameters:
#
# {   'a': 1.0903857973773616,
#     'gamma': 0.6094484128916543,
#     'log10_c': -3.483080439830831,
#     'log10_d': 2.273390059438432,
#     'log10_k0': -1.1358073063508662,
#     'log10_mu': -10.154310015964244,
#     'log10_tau': 3.686814581996265,
#     'omega': -0.23855125800980284,
#     'rho': 0.5395483923037744}
#
#     difference to previous: 0.02358964359277707
#     branching ratio: 1.0534047732072667
#
# iteration 16
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.339725
#       n_hat: 257.1850541592129
#
#   maximization
#
#     optimization step took  0:02:28.543745
#     new parameters:
#
# {   'a': 1.0844663108442292,
#     'gamma': 0.6040571085992223,
#     'log10_c': -3.4832569559317372,
#     'log10_d': 2.274900328031976,
#     'log10_k0': -1.1348237546042748,
#     'log10_mu': -10.156583120921901,
#     'log10_tau': 3.686745931520628,
#     'omega': -0.23855867521887494,
#     'rho': 0.539334776502799}
#
#     difference to previous: 0.01654391570994801
#     branching ratio: 1.0535488814037162
#
# iteration 17
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.340238
#       n_hat: 256.31449616658193
#
#   maximization
#
#     optimization step took  0:03:04.199668
#     new parameters:
#
# {   'a': 1.0801290593392463,
#     'gamma': 0.6001007836588004,
#     'log10_c': -3.4834558534874716,
#     'log10_d': 2.2760303108187196,
#     'log10_k0': -1.133998463939837,
#     'log10_mu': -10.158055678762937,
#     'log10_tau': 3.6866919345193545,
#     'omega': -0.23856349044897002,
#     'rho': 0.5392085368198503}
#
#     difference to previous: 0.012105357207673112
#     branching ratio: 1.0536562049075657
#
# iteration 18
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.372980
#       n_hat: 255.7547050256988
#
#   maximization
#
#     optimization step took  0:02:20.759632
#     new parameters:
#
# {   'a': 1.0769521813991538,
#     'gamma': 0.5972023858925861,
#     'log10_c': -3.4836811019404434,
#     'log10_d': 2.2768679686656843,
#     'log10_k0': -1.133338297140382,
#     'log10_mu': -10.159005215660622,
#     'log10_tau': 3.6866543412850747,
#     'omega': -0.23856713252417422,
#     'rho': 0.5391329242537024}
#
#     difference to previous: 0.008864733579015849
#     branching ratio: 1.053720080239663
#
# iteration 19
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.840158
#       n_hat: 255.39487481599463
#
#   maximization
#
#     optimization step took  0:02:19.767759
#     new parameters:
#
# {   'a': 1.0746275021437313,
#     'gamma': 0.5950865826285203,
#     'log10_c': -3.483781727230352,
#     'log10_d': 2.277491576416691,
#     'log10_k0': -1.132808666730846,
#     'log10_mu': -10.159616669945137,
#     'log10_tau': 3.686628734652486,
#     'omega': -0.2385685163353028,
#     'rho': 0.5390898157432018}
#
#     difference to previous: 0.006375899208672653
#     branching ratio: 1.0537603643665447
#
# iteration 20
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.350523
#       n_hat: 255.16370725279256
#
#   maximization
#
#     optimization step took  0:01:44.582519
#     new parameters:
#
# {   'a': 1.072892429039826,
#     'gamma': 0.5935142077045131,
#     'log10_c': -3.483851226085178,
#     'log10_d': 2.2779045473250408,
#     'log10_k0': -1.1325446119829898,
#     'log10_mu': -10.160009944321398,
#     'log10_tau': 3.6866036241661857,
#     'omega': -0.23857210295599598,
#     'rho': 0.53902770789775}
#
#     difference to previous: 0.004538051867650855
#     branching ratio: 1.0537858980753827
#
# iteration 21
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.337367
#       n_hat: 255.006355692645
#
#   maximization
#
#     optimization step took  0:02:35.043363
#     new parameters:
#
# {   'a': 1.0716241097717008,
#     'gamma': 0.5923496567647877,
#     'log10_c': -3.4839504184623937,
#     'log10_d': 2.2782380537620517,
#     'log10_k0': -1.1322468889506307,
#     'log10_mu': -10.160277842896487,
#     'log10_tau': 3.686592941885906,
#     'omega': -0.2385705785277849,
#     'rho': 0.5390076678829536}
#
#     difference to previous: 0.0034634373528127094
#     branching ratio: 1.0537969405367238
#
# iteration 22
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.337647
#       n_hat: 254.90586155273783
#
#   maximization
#
#     optimization step took  0:01:50.624575
#     new parameters:
#
# {   'a': 1.0706886835088207,
#     'gamma': 0.591471527938989,
#     'log10_c': -3.4840387827737116,
#     'log10_d': 2.278518771741461,
#     'log10_k0': -1.1319577839540056,
#     'log10_mu': -10.160449025502098,
#     'log10_tau': 3.686583445236453,
#     'omega': -0.2385715051151764,
#     'rho': 0.5390107153252891}
#
#     difference to previous: 0.002656395660821126
#     branching ratio: 1.0538095139946115
#
# iteration 23
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:03.076040
#       n_hat: 254.84371992345874
#
#   maximization
#
#     optimization step took  0:02:10.189539
#     new parameters:
#
# {   'a': 1.0699986941091795,
#     'gamma': 0.5908246067520543,
#     'log10_c': -3.484084133497935,
#     'log10_d': 2.278725714494828,
#     'log10_k0': -1.1317507196313066,
#     'log10_mu': -10.160554911873787,
#     'log10_tau': 3.6865777091661545,
#     'omega': -0.238571425250399,
#     'rho': 0.5390113759399691}
#
#     difference to previous: 0.0019086313083100381
#     branching ratio: 1.0538173849845662
#
# iteration 24
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.396118
#       n_hat: 254.80472106286496
#
#   maximization
#
#     optimization step took  0:01:25.822898
#     new parameters:
#
# {   'a': 1.069502890125626,
#     'gamma': 0.5903700135011882,
#     'log10_c': -3.484084899661266,
#     'log10_d': 2.2788782289262794,
#     'log10_k0': -1.1315695797394203,
#     'log10_mu': -10.16062137725905,
#     'log10_tau': 3.6865810736142497,
#     'omega': -0.23856980009027975,
#     'rho': 0.5390188456466691}
#
#     difference to previous: 0.0013637424212660232
#     branching ratio: 1.0538175547569424
#
# iteration 25
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.493794
#       n_hat: 254.780715007246
#
#   maximization
#
#     optimization step took  0:02:45.061724
#     new parameters:
#
# {   'a': 1.0691382466790365,
#     'gamma': 0.5900341605873671,
#     'log10_c': -3.484149314859202,
#     'log10_d': 2.2789893193051776,
#     'log10_k0': -1.1314509587726842,
#     'log10_mu': -10.160662295608583,
#     'log10_tau': 3.6865746631199516,
#     'omega': -0.23857053124095426,
#     'rho': 0.5390220974523302}
#
#     difference to previous: 0.0010459347041482103
#     branching ratio: 1.05382928054882
#
# iteration 26
#
#   expectation
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.338274
#       n_hat: 254.76615098576633
#
#   maximization
#
#     optimization step took  0:02:00.070266
#     new parameters:
#
# {   'a': 1.0688751804352907,
#     'gamma': 0.5897978596397371,
#     'log10_c': -3.484180026995425,
#     'log10_d': 2.279077715246125,
#     'log10_k0': -1.131343483380768,
#     'log10_mu': -10.160687121879088,
#     'log10_tau': 3.686576277787722,
#     'omega': -0.23857017325602348,
#     'rho': 0.5390294092671931}
#
#     difference to previous: 0.0007600613985301041
#     branching ratio: 1.0538265930579527
#
# stopping here. converged after 27 iterations.
#   last expectation step
#
#     calculating gij
#     calculating Pij
#     calculating n_hat and l_hat
#
#     expectation step took  0:00:02.337997
#       n_hat: 254.75792826926454
